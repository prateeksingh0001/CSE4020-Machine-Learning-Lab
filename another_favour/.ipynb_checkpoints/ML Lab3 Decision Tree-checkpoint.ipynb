# %% [markdown]
# # LAB3 :Decision Tree #
#
# ## Loading Libraries ##

# %%
from sklearn import datasets
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Reading Data from dataset ##

# %%
df = pd.read_csv('/home/sanchay1190/Downloads/cse_4020_machine_learning/Lab/day.csv', header=None)
df.tail()
y = df.iloc[1:150, 8].values
y = np.where(y == '2', -1, 1)
X = df.iloc[1:150, [9,11]].values

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
listname=list(df)
listname
# Out:
# ['instant',
#  'dteday',
#  'season',
#  'yr',
#  'mnth',
#  'holiday',
#  'weekday',
#  'workingday',
#  'weathersit',
#  'temp',
#  'atemp',
#  'hum',
#  'windspeed',
#  'casual',
#  'registered',
#  'cnt']

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/utils/validation.py:429: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)

# %%
from sklearn.linear_model import Perceptron
ppn = Perceptron(n_iter=40, eta0=0.1, random_state=0)
ppn.fit(X_train_std, y_train)
# Out:
# Perceptron(alpha=0.0001, class_weight=None, eta0=0.1, fit_intercept=True,
#       n_iter=40, n_jobs=1, penalty=None, random_state=0, shuffle=True,
#       verbose=0, warm_start=False)

# %%
from sklearn.tree import DecisionTreeClassifier 
from sklearn.cross_validation import train_test_split
tree = DecisionTreeClassifier(max_depth=4,random_state = 0)
tree.fit(X_train,y_train)
print("Accuracy on training set: {:.3f}".format(tree.score(X_train,y_train)))
print("Accuracy on test set: {:.3f}".format(tree.score(X_test,y_test)))
# Out:
# Accuracy on training set: 0.885
# Accuracy on test set: 0.756

# %%
from sklearn.tree import export_graphviz
export_graphviz(tree,out_file='tree.odt',class_names=['1','2'],feature_names=['temp', 'hum'],filled='weathersit')

# %%
import graphviz
with open("/home/sanchay1190/Downloads/cse_4020_machine_learning/Lab/tree.odt") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import train_test_split
import pandas as pd
import numpy as np
df = pd.read_csv('/home/sanchay1190/Downloads/cse_4020_machine_learning/Lab/day.csv', header=None)
feat_labels = df.columns.values[2:]
y = df.iloc[1:150, 8].values
y = np.where(y == '2', -1, 1)
X = df.iloc[1:150, 2:].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
forest = RandomForestClassifier(n_estimators=10000,random_state=0,n_jobs=-1)
forest.fit(X_train, y_train)
importances = forest.feature_importances_
indices = np.argsort(importances)[::-1]
for f in range(X_train.shape[1]):
    print("%2d) %-*s %f" % (f + 1, 30,listname[f+2],importances[indices[f]]))
# Out:
#  1) season                         0.493079
#  2) yr                             0.193897
#  3) mnth                           0.056047
#  4) holiday                        0.048834
#  5) weekday                        0.044646
#  6) workingday                     0.043145
#  7) weathersit                     0.040383
#  8) temp                           0.039125
#  9) atemp                          0.016396
# 10) hum                            0.014487
# 11) windspeed                      0.006588
# 12) casual                         0.003373
# 13) registered                     0.000000
# 14) cnt                            0.000000

# %%
plt.title('Feature Importances')
listname=listname[2:]
plt.bar(range(X_train.shape[1]),
importances[indices],
color='lightblue',
align='center')
plt.xticks(range(X_train.shape[1]),
listname, rotation=90)
plt.xlim([-1, X_train.shape[1]])
plt.tight_layout()
plt.show()
