# %% [markdown]
# # Lab Assignment 1
# ## Data Preprocessing
#
# ### Submitted to : Prof. Sweetlin Hemlatha
# ### Submitted by: Prateek Singh (15BCE1091)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = pd.read_csv("iris-data.csv")
data.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2
#
#          class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
data.dtypes
# Out:
# sepal_length_cm    float64
# sepal_width_cm     float64
# petal_length_cm    float64
# petal_width_cm     float64
# class               object
# dtype: object

# %%
data.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       150.000000      150.000000       150.000000      145.000000
# mean          5.644627        3.054667         3.758667        1.236552
# std           1.312781        0.433123         1.764420        0.755058
# min           0.055000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.400000
# 50%           5.700000        3.000000         4.350000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
sns.pairplot(data=data.dropna(),hue='class')

# %%
# Inference from previous cell missmatching class label (versicolor and setosa)
data.loc[data["class"] == "versicolor","class"] = "Iris-versicolor"
data.loc[data["class"] == "Iris-setossa","class"] = "Iris-setosa"

# %%
sns.pairplot(data=data.dropna(),hue='class') #Plot after fixing class labels

# %%
data.loc[data["class"]=="Iris-setosa","sepal_width_cm"].hist()

# %%
data.loc[data["petal_width_cm"].isnull()]
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 7               5.0             3.4              1.5             NaN
# 8               4.4             2.9              1.4             NaN
# 9               4.9             3.1              1.5             NaN
# 10              5.4             3.7              1.5             NaN
# 11              4.8             3.4              1.6             NaN
#
#           class
# 7   Iris-setosa
# 8   Iris-setosa
# 9   Iris-setosa
# 10  Iris-setosa
# 11  Iris-setosa

# %%
#Fixing missing values of petal_width_cm from data.describe() mean
data.loc[data["petal_width_cm"].isnull(),"petal_width_cm"] = 1.236552
data.loc[data["petal_width_cm"].isnull()]
# Out:
# Empty DataFrame
# Columns: [sepal_length_cm, sepal_width_cm, petal_length_cm, petal_width_cm, class]
# Index: []

# %%
sns.violinplot(data=data) # Violin Plot// They represent probability density also when compared with box plot

# %%
sns.boxplot(data=data) #Box plot representing mean and quantiles

# %% [markdown]
# #### Applying the above functions to my own dataset

# %%
wine_data = pd.read_csv('../Dataset/winequality-white.csv', sep=';')
red_wine = pd.read_csv('../Dataset/winequality-red.csv', sep=';')
sns.set(style='whitegrid', context='notebook', font_scale=1)

# %%
    wine_data.append(red_wine)
wine_data["quality"] = wine_data["quality"].astype(str)
wine_data.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
wine_data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
wine_data.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                  object
# dtype: object

# %%
sns.pairplot(wine_data.dropna(), size=2.5, hue="quality")

# %%
wine_data.loc[wine_data["quality"]=='5',"fixed acidity"].hist()

# %%
sns.violinplot(data=wine_data["density"], size=10)

# %%
sns.violinplot(data=wine_data["citr"], size=10)

# %%
sns.violinplot(data=wine_data["sulphates"], size=10)

# %%
sns.violinplot(data=wine_data["pH"], size=10)

# %%
fig, ax = plt.subplots(figsize=(20, 20))
# seaborn.violinplot(ax=ax, data=df, **violin_options)
sns.boxplot(ax=ax, data=wine_data)
